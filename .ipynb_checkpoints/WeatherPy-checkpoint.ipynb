# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []


# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ## Perform API Calls

# %%
country = []
cloudiness = []
temp = []
humidity = []
wind = []
lat = []
lng = []

cities_pd = pd.DataFrame({"Cities": cities})
cities_pd["Country"] = ""
cities_pd["Lat"] = ""
cities_pd["Lng"] = ""
cities_pd["Temp"] = ""
cities_pd["Humidity"] = ""
cities_pd["Cloudiness"] = ""
cities_pd["Wind Speed"] = ""
cities_pd.head()
# Out:
#          Cities Country Lat Lng Temp Humidity Cloudiness Wind Speed
# 0         kapaa
# 1  punta arenas
# 2   pangnirtung
# 3   east london
# 4     tamandare

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
units = "Imperial"
url = "http://api.openweathermap.org/data/2.5/weather?"

count = 0
Number_cities = len(cities)
for city in cities:
    query_url = f'{url}appid={api_key}&units={units}&q={city}'
    cities_data = requests.get(query_url).json()
    print(f'city {count} of {Number_cities} | {city}')
    print(f'Extracting {query_url}')
    count = count + 1
    print('------------------------')     
       
    try:      
        country.append(cities_data["sys"]["country"])
        lat.append(cities_data["coord"]["lat"])
        lng.append(cities_data["coord"]["lon"])
        temp.append(cities_data["main"]["temp"])
        humidity.append(cities_data["main"]["humidity"])
        cloudiness.append(cities_data["clouds"]["all"])
        wind.append(cities_data["wind"]["speed"])
         
    except: 
        print("City not Found")
print("extracted all data")
# Out:
# city 0 of 624 | kapaa
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=kapaa
# ------------------------
# City not Found
# city 1 of 624 | punta arenas
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=punta arenas
# ------------------------
# City not Found
# city 2 of 624 | pangnirtung
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=pangnirtung
# ------------------------
# City not Found
# city 3 of 624 | east london
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=east london
# ------------------------
# City not Found
# city 4 of 624 | tamandare
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=tamandare
# ------------------------
# City not Found
# city 5 of 624 | saskylakh
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=saskylakh
# ------------------------
# City not Found
# city 6 of 624 | chokurdakh
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=chokurdakh
# ------------------------
# City not Found
# city 7 of 624 | castanos
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=castanos
# ------------------------
# City not Found
# city 8 of 624 | thompson
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=thompson
# ------------------------
# City not Found
# city 9 of 624 | albany
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=albany
# ------------------------
# City not Found
# city 10 of 624 | mount gambier
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=mount gambier
# ------------------------
# City not Found
# city 11 of 624 | busselton
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=busselton
# ------------------------
# City not Found
# city 12 of 624 | provideniya
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=provideniya
# ------------------------
# City not Found
# city 13 of 624 | santa cruz
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=santa cruz
# ------------------------
# City not Found
# city 14 of 624 | mackay
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=mackay
# ------------------------
# City not Found
# city 15 of 624 | srednekolymsk
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=srednekolymsk
# ------------------------
# City not Found
# city 16 of 624 | palabuhanratu
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=palabuhanratu
# ------------------------
# City not Found
# city 17 of 624 | kargasok
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=kargasok
# ------------------------
# City not Found
# city 18 of 624 | coquimbo
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=coquimbo
# ------------------------
# City not Found
# city 19 of 624 | puerto quijarro
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=puerto quijarro
# ------------------------
# City not Found
# city 20 of 624 | grand river south east
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=grand river south east
# ------------------------
# City not Found
# city 21 of 624 | hermanus
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=hermanus
# ------------------------
# City not Found
# city 22 of 624 | georgetown
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=georgetown
# ------------------------
# City not Found
# city 23 of 624 | college
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=college
# ------------------------
# City not Found
# city 24 of 624 | upernavik
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=upernavik
# ------------------------
# City not Found
# city 25 of 624 | hithadhoo
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=hithadhoo
# ------------------------
# City not Found
# city 26 of 624 | mataura
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=mataura
# ------------------------
# City not Found
# city 27 of 624 | quatre cocos
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=quatre cocos
# ------------------------
# City not Found
# city 28 of 624 | ushuaia
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=ushuaia
# ------------------------
# City not Found
# city 29 of 624 | longyearbyen
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=longyearbyen
# ------------------------
# City not Found
# city 30 of 624 | kichera
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=kichera
# ------------------------
# City not Found
# city 31 of 624 | taolanaro
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=taolanaro
# ------------------------
# City not Found
# city 32 of 624 | cape town
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=cape town
# ------------------------
# City not Found
# city 33 of 624 | thinadhoo
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=thinadhoo
# ------------------------
# City not Found
# city 34 of 624 | deep river
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=deep river
# ------------------------
# City not Found
# city 35 of 624 | talnakh
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=talnakh
# ------------------------
# City not Found
# city 36 of 624 | beckley
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=beckley
# ------------------------
# City not Found
# city 37 of 624 | amderma
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=amderma
# ------------------------
# City not Found
# city 38 of 624 | bluff
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=bluff
# ------------------------
# City not Found
# city 39 of 624 | rikitea
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=rikitea
# ------------------------
# City not Found
# city 40 of 624 | bargal
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=bargal
# ------------------------
# City not Found
# city 41 of 624 | padang
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=padang
# ------------------------
# City not Found
# city 42 of 624 | salinopolis
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=salinopolis
# ------------------------
# City not Found
# city 43 of 624 | ostrovnoy
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=ostrovnoy
# ------------------------
# City not Found
# city 44 of 624 | belushya guba
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=belushya guba
# ------------------------
# City not Found
# city 45 of 624 | soverato
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=soverato
# ------------------------
# City not Found
# city 46 of 624 | sibolga
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=sibolga
# ------------------------
# City not Found
# city 47 of 624 | yellowknife
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=yellowknife
# ------------------------
# City not Found
# city 48 of 624 | unai
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=unai
# ------------------------
# City not Found
# city 49 of 624 | katsuura
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=katsuura
# ------------------------
# City not Found
# city 50 of 624 | itoman
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=itoman
# ------------------------
# City not Found
# city 51 of 624 | tromso
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=tromso
# ------------------------
# City not Found
# city 52 of 624 | jimenez
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=jimenez
# ------------------------
# City not Found
# city 53 of 624 | saint-philippe
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=saint-philippe
# ------------------------
# City not Found
# city 54 of 624 | prince rupert
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=prince rupert
# ------------------------
# City not Found
# city 55 of 624 | nanakuli
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=nanakuli
# ------------------------
# City not Found
# city 56 of 624 | carinhanha
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=carinhanha
# ------------------------
# City not Found
# city 57 of 624 | nanortalik
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=nanortalik
# ------------------------
# City not Found
# city 58 of 624 | kaitangata
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=kaitangata
# ------------------------
# City not Found
# city 59 of 624 | attawapiskat
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=attawapiskat
# ------------------------
# City not Found
# city 60 of 624 | ancud
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=ancud
# ------------------------
# City not Found
# city 61 of 624 | eruwa
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=eruwa
# ------------------------
# City not Found
# city 62 of 624 | banjarmasin
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=banjarmasin
# ------------------------
# City not Found
# city 63 of 624 | port alfred
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=port alfred
# ------------------------
# City not Found
# city 64 of 624 | los llanos de aridane
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=los llanos de aridane
# ------------------------
# City not Found
# city 65 of 624 | gobabis
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=gobabis
# ------------------------
# City not Found
# city 66 of 624 | jumla
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=jumla
# ------------------------
# City not Found
# city 67 of 624 | satitoa
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=satitoa
# ------------------------
# City not Found
# city 68 of 624 | northam
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=northam
# ------------------------
# City not Found
# city 69 of 624 | andevoranto
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=andevoranto
# ------------------------
# City not Found
# city 70 of 624 | vaini
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=vaini
# ------------------------
# City not Found
# city 71 of 624 | high level
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=high level
# ------------------------
# City not Found
# city 72 of 624 | saint pete beach
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=saint pete beach
# ------------------------
# City not Found
# city 73 of 624 | saldanha
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=saldanha
# ------------------------
# City not Found
# city 74 of 624 | avarua
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=avarua
# ------------------------
# City not Found
# city 75 of 624 | kununurra
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=kununurra
# ------------------------
# City not Found
# city 76 of 624 | artyk
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=artyk
# ------------------------
# City not Found
# city 77 of 624 | san patricio
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=san patricio
# ------------------------
# City not Found
# city 78 of 624 | atar
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=atar
# ------------------------
# City not Found
# city 79 of 624 | chuy
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=chuy
# ------------------------
# City not Found
# city 80 of 624 | narwana
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=narwana
# ------------------------
# City not Found
# city 81 of 624 | sitka
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=sitka
# ------------------------
# City not Found
# city 82 of 624 | belaya gora
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=belaya gora
# ------------------------
# City not Found
# city 83 of 624 | jamestown
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=jamestown
# ------------------------
# City not Found
# city 84 of 624 | puerto ayora
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=puerto ayora
# ------------------------
# City not Found
# city 85 of 624 | maragogi
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=maragogi
# ------------------------
# City not Found
# city 86 of 624 | hulyaypole
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=hulyaypole
# ------------------------
# City not Found
# city 87 of 624 | butaritari
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=butaritari
# ------------------------
# City not Found
# city 88 of 624 | rancho palos verdes
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=rancho palos verdes
# ------------------------
# City not Found
# city 89 of 624 | castro
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=castro
# ------------------------
# City not Found
# city 90 of 624 | barrow
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=barrow
# ------------------------
# City not Found
# city 91 of 624 | kodiak
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=kodiak
# ------------------------
# City not Found
# city 92 of 624 | yulara
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=yulara
# ------------------------
# City not Found
# city 93 of 624 | zambezi
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=zambezi
# ------------------------
# City not Found
# city 94 of 624 | itarema
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=itarema
# ------------------------
# City not Found
# city 95 of 624 | cabo san lucas
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=cabo san lucas
# ------------------------
# City not Found
# city 96 of 624 | kangaatsiaq
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=kangaatsiaq
# ------------------------
# City not Found
# city 97 of 624 | stokmarknes
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=stokmarknes
# ------------------------
# City not Found
# city 98 of 624 | payo
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=payo
# ------------------------
# City not Found
# city 99 of 624 | dongsheng
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=dongsheng
# ------------------------
# City not Found
# city 100 of 624 | turangi
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=turangi
# ------------------------
# City not Found
# city 101 of 624 | yeniseysk
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=yeniseysk
# ------------------------
# City not Found
# city 102 of 624 | diamantino
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=diamantino
# ------------------------
# City not Found
# city 103 of 624 | jaswantnagar
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=jaswantnagar
# ------------------------
# City not Found
# city 104 of 624 | saint-pierre
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=saint-pierre
# ------------------------
# City not Found
# city 105 of 624 | sao filipe
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=sao filipe
# ------------------------
# City not Found
# city 106 of 624 | byron bay
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=byron bay
# ------------------------
# City not Found
# city 107 of 624 | codrington
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=codrington
# ------------------------
# City not Found
# city 108 of 624 | chicama
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=chicama
# ------------------------
# City not Found
# city 109 of 624 | stornoway
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=stornoway
# ------------------------
# City not Found
# city 110 of 624 | atuona
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=atuona
# ------------------------
# City not Found
# city 111 of 624 | praia da vitoria
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=praia da vitoria
# ------------------------
# City not Found
# city 112 of 624 | madimba
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=madimba
# ------------------------
# City not Found
# city 113 of 624 | alpoyeca
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=alpoyeca
# ------------------------
# City not Found
# city 114 of 624 | qaanaaq
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=qaanaaq
# ------------------------
# City not Found
# city 115 of 624 | new norfolk
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=new norfolk
# ------------------------
# City not Found
# city 116 of 624 | le port
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=le port
# ------------------------
# City not Found
# city 117 of 624 | zhanaozen
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=zhanaozen
# ------------------------
# City not Found
# city 118 of 624 | imbituba
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=imbituba
# ------------------------
# City not Found
# city 119 of 624 | arraial do cabo
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=arraial do cabo
# ------------------------
# City not Found
# city 120 of 624 | ngukurr
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=ngukurr
# ------------------------
# City not Found
# city 121 of 624 | barentsburg
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=barentsburg
# ------------------------
# City not Found
# city 122 of 624 | campo grande
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=campo grande
# ------------------------
# City not Found
# city 123 of 624 | victoria
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=victoria
# ------------------------
# City not Found
# city 124 of 624 | mount isa
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=mount isa
# ------------------------
# City not Found
# city 125 of 624 | tasiilaq
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=tasiilaq
# ------------------------
# City not Found
# city 126 of 624 | roura
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=roura
# ------------------------
# City not Found
# city 127 of 624 | palana
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=palana
# ------------------------
# City not Found
# city 128 of 624 | faanui
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=faanui
# ------------------------
# City not Found
# city 129 of 624 | awjilah
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=awjilah
# ------------------------
# City not Found
# city 130 of 624 | keti bandar
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=keti bandar
# ------------------------
# City not Found
# city 131 of 624 | kutum
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=kutum
# ------------------------
# City not Found
# city 132 of 624 | tiksi
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=tiksi
# ------------------------
# City not Found
# city 133 of 624 | allapalli
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=allapalli
# ------------------------
# City not Found
# city 134 of 624 | oistins
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=oistins
# ------------------------
# City not Found
# city 135 of 624 | palmas bellas
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=palmas bellas
# ------------------------
# City not Found
# city 136 of 624 | viedma
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=viedma
# ------------------------
# City not Found
# city 137 of 624 | la rochelle
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=la rochelle
# ------------------------
# City not Found
# city 138 of 624 | morehead
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=morehead
# ------------------------
# City not Found
# city 139 of 624 | bredasdorp
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=bredasdorp
# ------------------------
# City not Found
# city 140 of 624 | solwezi
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=solwezi
# ------------------------
# City not Found
# city 141 of 624 | nara
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=nara
# ------------------------
# City not Found
# city 142 of 624 | svrljig
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=svrljig
# ------------------------
# City not Found
# city 143 of 624 | vardo
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=vardo
# ------------------------
# City not Found
# city 144 of 624 | beyneu
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=beyneu
# ------------------------
# City not Found
# city 145 of 624 | tuatapere
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=tuatapere
# ------------------------
# City not Found
# city 146 of 624 | bursol
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=bursol
# ------------------------
# City not Found
# city 147 of 624 | atikokan
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=atikokan
# ------------------------
# City not Found
# city 148 of 624 | illoqqortoormiut
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=illoqqortoormiut
# ------------------------
# City not Found
# city 149 of 624 | airai
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=airai
# ------------------------
# City not Found
# city 150 of 624 | alyangula
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=alyangula
# ------------------------
# City not Found
# city 151 of 624 | varzea da palma
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=varzea da palma
# ------------------------
# City not Found
# city 152 of 624 | port elizabeth
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=port elizabeth
# ------------------------
# City not Found
# city 153 of 624 | yakeshi
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=yakeshi
# ------------------------
# City not Found
# city 154 of 624 | narsaq
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=narsaq
# ------------------------
# City not Found
# city 155 of 624 | vila do maio
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=vila do maio
# ------------------------
# City not Found
# city 156 of 624 | nikolskoye
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=nikolskoye
# ------------------------
# City not Found
# city 157 of 624 | clyde river
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=clyde river
# ------------------------
# City not Found
# city 158 of 624 | glendive
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=glendive
# ------------------------
# City not Found
# city 159 of 624 | shenjiamen
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=shenjiamen
# ------------------------
# City not Found
# city 160 of 624 | dikson
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=dikson
# ------------------------
# City not Found
# city 161 of 624 | khatanga
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=khatanga
# ------------------------
# City not Found
# city 162 of 624 | touros
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=touros
# ------------------------
# City not Found
# city 163 of 624 | vaitupu
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=vaitupu
# ------------------------
# City not Found
# city 164 of 624 | belyy yar
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=belyy yar
# ------------------------
# City not Found
# city 165 of 624 | nizhniy kuranakh
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=nizhniy kuranakh
# ------------------------
# City not Found
# city 166 of 624 | naze
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=naze
# ------------------------
# City not Found
# city 167 of 624 | gwanda
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=gwanda
# ------------------------
# City not Found
# city 168 of 624 | umzimvubu
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=umzimvubu
# ------------------------
# City not Found
# city 169 of 624 | olga
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=olga
# ------------------------
# City not Found
# city 170 of 624 | daura
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=daura
# ------------------------
# City not Found
# city 171 of 624 | hobart
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=hobart
# ------------------------
# City not Found
# city 172 of 624 | bhan
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=bhan
# ------------------------
# City not Found
# city 173 of 624 | torbat-e jam
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=torbat-e jam
# ------------------------
# City not Found
# city 174 of 624 | tsihombe
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=tsihombe
# ------------------------
# City not Found
# city 175 of 624 | umm durman
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=umm durman
# ------------------------
# City not Found
# city 176 of 624 | carahue
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=carahue
# ------------------------
# City not Found
# city 177 of 624 | norman wells
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=norman wells
# ------------------------
# City not Found
# city 178 of 624 | saint george
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=saint george
# ------------------------
# City not Found
# city 179 of 624 | scottsburgh
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=scottsburgh
# ------------------------
# City not Found
# city 180 of 624 | maku
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=maku
# ------------------------
# City not Found
# city 181 of 624 | hobyo
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=hobyo
# ------------------------
# City not Found
# city 182 of 624 | turayf
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=turayf
# ------------------------
# City not Found
# city 183 of 624 | tuktoyaktuk
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=tuktoyaktuk
# ------------------------
# City not Found
# city 184 of 624 | hilo
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=hilo
# ------------------------
# City not Found
# city 185 of 624 | bethel
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=bethel
# ------------------------
# City not Found
# city 186 of 624 | tateyama
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=tateyama
# ------------------------
# City not Found
# city 187 of 624 | luan
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=luan
# ------------------------
# City not Found
# city 188 of 624 | antigua ocotepeque
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=antigua ocotepeque
# ------------------------
# City not Found
# city 189 of 624 | faya
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=faya
# ------------------------
# City not Found
# city 190 of 624 | tall kayf
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=tall kayf
# ------------------------
# City not Found
# city 191 of 624 | grand gaube
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=grand gaube
# ------------------------
# City not Found
# city 192 of 624 | abeche
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=abeche
# ------------------------
# City not Found
# city 193 of 624 | hall
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=hall
# ------------------------
# City not Found
# city 194 of 624 | san luis
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=san luis
# ------------------------
# City not Found
# city 195 of 624 | kadnikov
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=kadnikov
# ------------------------
# City not Found
# city 196 of 624 | hasaki
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=hasaki
# ------------------------
# City not Found
# city 197 of 624 | alofi
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=alofi
# ------------------------
# City not Found
# city 198 of 624 | hambantota
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=hambantota
# ------------------------
# City not Found
# city 199 of 624 | kety
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=kety
# ------------------------
# City not Found
# city 200 of 624 | severo-kurilsk
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=severo-kurilsk
# ------------------------
# City not Found
# city 201 of 624 | ler
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=ler
# ------------------------
# City not Found
# city 202 of 624 | sioux lookout
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=sioux lookout
# ------------------------
# City not Found
# city 203 of 624 | bilibino
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=bilibino
# ------------------------
# City not Found
# city 204 of 624 | aswan
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=aswan
# ------------------------
# City not Found
# city 205 of 624 | debar
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=debar
# ------------------------
# City not Found
# city 206 of 624 | geraldton
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=geraldton
# ------------------------
# City not Found
# city 207 of 624 | pimenta bueno
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=pimenta bueno
# ------------------------
# City not Found
# city 208 of 624 | dmitrov
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=dmitrov
# ------------------------
# City not Found
# city 209 of 624 | bambanglipuro
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=bambanglipuro
# ------------------------
# City not Found
# city 210 of 624 | lebu
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=lebu
# ------------------------
# City not Found
# city 211 of 624 | iqaluit
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=iqaluit
# ------------------------
# City not Found
# city 212 of 624 | bambous virieux
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=bambous virieux
# ------------------------
# City not Found
# city 213 of 624 | torbay
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=torbay
# ------------------------
# City not Found
# city 214 of 624 | frutal
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=frutal
# ------------------------
# City not Found
# city 215 of 624 | ryotsu
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=ryotsu
# ------------------------
# City not Found
# city 216 of 624 | hatillo
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=hatillo
# ------------------------
# City not Found
# city 217 of 624 | vao
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=vao
# ------------------------
# City not Found
# city 218 of 624 | champawat
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=champawat
# ------------------------
# City not Found
# city 219 of 624 | constitucion
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=constitucion
# ------------------------
# City not Found
# city 220 of 624 | chanika
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=chanika
# ------------------------
# City not Found
# city 221 of 624 | bolungarvik
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=bolungarvik
# ------------------------
# City not Found
# city 222 of 624 | pisco
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=pisco
# ------------------------
# City not Found
# city 223 of 624 | galesong
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=galesong
# ------------------------
# City not Found
# city 224 of 624 | paamiut
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=paamiut
# ------------------------
# City not Found
# city 225 of 624 | flin flon
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=flin flon
# ------------------------
# City not Found
# city 226 of 624 | karlstad
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=karlstad
# ------------------------
# City not Found
# city 227 of 624 | naifaru
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=naifaru
# ------------------------
# City not Found
# city 228 of 624 | dali
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=dali
# ------------------------
# City not Found
# city 229 of 624 | dukat
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=dukat
# ------------------------
# City not Found
# city 230 of 624 | acapulco
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=acapulco
# ------------------------
# City not Found
# city 231 of 624 | nizhneyansk
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=nizhneyansk
# ------------------------
# City not Found
# city 232 of 624 | valea danului
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=valea danului
# ------------------------
# City not Found
# city 233 of 624 | mys shmidta
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=mys shmidta
# ------------------------
# City not Found
# city 234 of 624 | atherton
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=atherton
# ------------------------
# City not Found
# city 235 of 624 | liptovsky hradok
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=liptovsky hradok
# ------------------------
# City not Found
# city 236 of 624 | ilulissat
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=ilulissat
# ------------------------
# City not Found
# city 237 of 624 | camargo
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=camargo
# ------------------------
# City not Found
# city 238 of 624 | chernyshevskiy
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=chernyshevskiy
# ------------------------
# City not Found
# city 239 of 624 | elat
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=elat
# ------------------------
# City not Found
# city 240 of 624 | maine-soroa
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=maine-soroa
# ------------------------
# City not Found
# city 241 of 624 | ugoofaaru
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=ugoofaaru
# ------------------------
# City not Found
# city 242 of 624 | lasa
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=lasa
# ------------------------
# City not Found
# city 243 of 624 | komsomolskiy
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=komsomolskiy
# ------------------------
# City not Found
# city 244 of 624 | miranpur
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=miranpur
# ------------------------
# City not Found
# city 245 of 624 | mahebourg
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=mahebourg
# ------------------------
# City not Found
# city 246 of 624 | fort nelson
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=fort nelson
# ------------------------
# City not Found
# city 247 of 624 | saint-augustin
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=saint-augustin
# ------------------------
# City not Found
# city 248 of 624 | lethem
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=lethem
# ------------------------
# City not Found
# city 249 of 624 | kharhial
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=kharhial
# ------------------------
# City not Found
# city 250 of 624 | egvekinot
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=egvekinot
# ------------------------
# City not Found
# city 251 of 624 | puerto leguizamo
# ...
# ------------------------
# City not Found
# city 541 of 624 | markova
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=markova
# ------------------------
# City not Found
# city 542 of 624 | port hedland
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=port hedland
# ------------------------
# City not Found
# city 543 of 624 | valparaiso
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=valparaiso
# ------------------------
# City not Found
# city 544 of 624 | nome
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=nome
# ------------------------
# City not Found
# city 545 of 624 | eureka
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=eureka
# ------------------------
# City not Found
# city 546 of 624 | indramayu
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=indramayu
# ------------------------
# City not Found
# city 547 of 624 | bathsheba
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=bathsheba
# ------------------------
# City not Found
# city 548 of 624 | tynset
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=tynset
# ------------------------
# City not Found
# city 549 of 624 | chone
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=chone
# ------------------------
# City not Found
# city 550 of 624 | sept-iles
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=sept-iles
# ------------------------
# City not Found
# city 551 of 624 | lata
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=lata
# ------------------------
# City not Found
# city 552 of 624 | hammerfest
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=hammerfest
# ------------------------
# City not Found
# city 553 of 624 | aberystwyth
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=aberystwyth
# ------------------------
# City not Found
# city 554 of 624 | espanola
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=espanola
# ------------------------
# City not Found
# city 555 of 624 | aykhal
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=aykhal
# ------------------------
# City not Found
# city 556 of 624 | xinyu
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=xinyu
# ------------------------
# City not Found
# city 557 of 624 | takoradi
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=takoradi
# ------------------------
# City not Found
# city 558 of 624 | maceio
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=maceio
# ------------------------
# City not Found
# city 559 of 624 | saravan
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=saravan
# ------------------------
# City not Found
# city 560 of 624 | mnogovershinnyy
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=mnogovershinnyy
# ------------------------
# City not Found
# city 561 of 624 | uige
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=uige
# ------------------------
# City not Found
# city 562 of 624 | linxia
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=linxia
# ------------------------
# City not Found
# city 563 of 624 | les cayes
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=les cayes
# ------------------------
# City not Found
# city 564 of 624 | tesalia
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=tesalia
# ------------------------
# City not Found
# city 565 of 624 | vichy
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=vichy
# ------------------------
# City not Found
# city 566 of 624 | progreso
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=progreso
# ------------------------
# City not Found
# city 567 of 624 | grand centre
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=grand centre
# ------------------------
# City not Found
# city 568 of 624 | lolua
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=lolua
# ------------------------
# City not Found
# city 569 of 624 | barcelos
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=barcelos
# ------------------------
# City not Found
# city 570 of 624 | ronchin
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=ronchin
# ------------------------
# City not Found
# city 571 of 624 | karkaralinsk
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=karkaralinsk
# ------------------------
# City not Found
# city 572 of 624 | kingman
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=kingman
# ------------------------
# City not Found
# city 573 of 624 | adre
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=adre
# ------------------------
# City not Found
# city 574 of 624 | manzhouli
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=manzhouli
# ------------------------
# City not Found
# city 575 of 624 | yerofey pavlovich
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=yerofey pavlovich
# ------------------------
# City not Found
# city 576 of 624 | presidencia roque saenz pena
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=presidencia roque saenz pena
# ------------------------
# City not Found
# city 577 of 624 | ludvika
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=ludvika
# ------------------------
# City not Found
# city 578 of 624 | sasca montana
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=sasca montana
# ------------------------
# City not Found
# city 579 of 624 | portland
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=portland
# ------------------------
# City not Found
# city 580 of 624 | phalaborwa
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=phalaborwa
# ------------------------
# City not Found
# city 581 of 624 | shchelyayur
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=shchelyayur
# ------------------------
# City not Found
# city 582 of 624 | namatanai
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=namatanai
# ------------------------
# City not Found
# city 583 of 624 | sakaiminato
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=sakaiminato
# ------------------------
# City not Found
# city 584 of 624 | bud
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=bud
# ------------------------
# City not Found
# city 585 of 624 | vitim
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=vitim
# ------------------------
# City not Found
# city 586 of 624 | carutapera
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=carutapera
# ------------------------
# City not Found
# city 587 of 624 | gamba
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=gamba
# ------------------------
# City not Found
# city 588 of 624 | chudovo
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=chudovo
# ------------------------
# City not Found
# city 589 of 624 | kokoda
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=kokoda
# ------------------------
# City not Found
# city 590 of 624 | kurayoshi
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=kurayoshi
# ------------------------
# City not Found
# city 591 of 624 | miri
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=miri
# ------------------------
# City not Found
# city 592 of 624 | rudkobing
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=rudkobing
# ------------------------
# City not Found
# city 593 of 624 | olinda
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=olinda
# ------------------------
# City not Found
# city 594 of 624 | hereford
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=hereford
# ------------------------
# City not Found
# city 595 of 624 | santa vitoria do palmar
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=santa vitoria do palmar
# ------------------------
# City not Found
# city 596 of 624 | japura
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=japura
# ------------------------
# City not Found
# city 597 of 624 | broken hill
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=broken hill
# ------------------------
# City not Found
# city 598 of 624 | lompoc
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=lompoc
# ------------------------
# City not Found
# city 599 of 624 | orangeburg
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=orangeburg
# ------------------------
# City not Found
# city 600 of 624 | tsaratanana
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=tsaratanana
# ------------------------
# City not Found
# city 601 of 624 | vung tau
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=vung tau
# ------------------------
# City not Found
# city 602 of 624 | isangel
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=isangel
# ------------------------
# City not Found
# city 603 of 624 | santiago de cao
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=santiago de cao
# ------------------------
# City not Found
# city 604 of 624 | funadhoo
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=funadhoo
# ------------------------
# City not Found
# city 605 of 624 | adilabad
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=adilabad
# ------------------------
# City not Found
# city 606 of 624 | palu
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=palu
# ------------------------
# City not Found
# city 607 of 624 | san carlos de bariloche
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=san carlos de bariloche
# ------------------------
# City not Found
# city 608 of 624 | shahada
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=shahada
# ------------------------
# City not Found
# city 609 of 624 | nueva loja
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=nueva loja
# ------------------------
# City not Found
# city 610 of 624 | jomalig
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=jomalig
# ------------------------
# City not Found
# city 611 of 624 | zhezkazgan
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=zhezkazgan
# ------------------------
# City not Found
# city 612 of 624 | cuamba
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=cuamba
# ------------------------
# City not Found
# city 613 of 624 | kieta
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=kieta
# ------------------------
# City not Found
# city 614 of 624 | nyimba
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=nyimba
# ------------------------
# City not Found
# city 615 of 624 | pakwach
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=pakwach
# ------------------------
# City not Found
# city 616 of 624 | havelock
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=havelock
# ------------------------
# City not Found
# city 617 of 624 | juneau
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=juneau
# ------------------------
# City not Found
# city 618 of 624 | mahibadhoo
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=mahibadhoo
# ------------------------
# City not Found
# city 619 of 624 | tiznit
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=tiznit
# ------------------------
# City not Found
# city 620 of 624 | jiroft
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=jiroft
# ------------------------
# City not Found
# city 621 of 624 | kemijarvi
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=kemijarvi
# ------------------------
# City not Found
# city 622 of 624 | manaure
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=manaure
# ------------------------
# City not Found
# city 623 of 624 | kahului
# Extracting http://api.openweathermap.org/data/2.5/weather?appid=84505d36724dae8ffe13d73f71897316&units=Imperial&q=kahului
# ------------------------
# City not Found
# extracted all data

# %%
#country = (cities_data["sys"]["country"])
#lat = (cities_data["coord"]["lat"])
#lng = (cities_data["coord"]["lon"])
#temp = (cities_data["main"]["temp"])
#humidity = (cities_data["main"]["humidity"])
#cloudiness = (cities_data["clouds"]["all"])
#wind = (cities_data["wind"]["speed"])

for index, row in cities_pd.iterrows():
    cities_pd.at[index, "Country"] = country
    #(cities_data["sys"]["country"])
    cities_pd.at[index, "Lat"] = lat
    #(cities_data["coord"]["lat"])
    cities_pd.at[index, "Lng"] = lng
    #(cities_data["coord"]["lon"])
    cities_pd.at[index, "Temp"] = temp
    #(cities_data["main"]["temp"])
    cities_pd.at[index, "Humidity"] = humidity
    #(cities_data["main"]["humidity"])
    cities_pd.at[index, "Cloudiness"] = cloudiness
    #(cities_data["clouds"]["all"])
    cities_pd.at[index, "Wind Speed"] = wind
    #(cities_data["wind"]["speed"])

cities_pd.head()
# Out:
#          Cities Country    Lat  \
# 0         kapaa      US  20.89
# 1  punta arenas      US  20.89
# 2   pangnirtung      US  20.89
# 3   east london      US  20.89
# 4     tamandare      US  20.89
#
#                                                  Lng  \
# 0  [-159.32, -70.91, -65.72, 27.91, -70.75, 114.0...
# 1  [-159.32, -70.91, -65.72, 27.91, -70.75, 114.0...
# 2  [-159.32, -70.91, -65.72, 27.91, -70.75, 114.0...
# 3  [-159.32, -70.91, -65.72, 27.91, -70.75, 114.0...
# 4  [-159.32, -70.91, -65.72, 27.91, -70.75, 114.0...
#
#                                                 Temp  \
# 0  [82.53, 35.6, 31.93, 64.87, 77.2, 41.92, 54.88...
# 1  [82.53, 35.6, 31.93, 64.87, 77.2, 41.92, 54.88...
# 2  [82.53, 35.6, 31.93, 64.87, 77.2, 41.92, 54.88...
# 3  [82.53, 35.6, 31.93, 64.87, 77.2, 41.92, 54.88...
# 4  [82.53, 35.6, 31.93, 64.87, 77.2, 41.92, 54.88...
#
#                                             Humidity  \
# 0  [74, 100, 84, 100, 71, 89, 78, 63, 50, 56, 82,...
# 1  [74, 100, 84, 100, 71, 89, 78, 63, 50, 56, 82,...
# 2  [74, 100, 84, 100, 71, 89, 78, 63, 50, 56, 82,...
# 3  [74, 100, 84, 100, 71, 89, 78, 63, 50, 56, 82,...
# 4  [74, 100, 84, 100, 71, 89, 78, 63, 50, 56, 82,...
#
#                                           Cloudiness  \
# 0  [40, 75, 0, 0, 0, 76, 92, 56, 75, 20, 92, 0, 3...
# 1  [40, 75, 0, 0, 0, 76, 92, 56, 75, 20, 92, 0, 3...
# 2  [40, 75, 0, 0, 0, 76, 92, 56, 75, 20, 92, 0, 3...
# 3  [40, 75, 0, 0, 0, 76, 92, 56, 75, 20, 92, 0, 3...
# 4  [40, 75, 0, 0, 0, 76, 92, 56, 75, 20, 92, 0, 3...
#
#                                           Wind Speed
# 0  [18.34, 6.93, 4.41, 9.66, 3.62, 8.21, 13.35, 3...
# 1  [18.34, 6.93, 4.41, 9.66, 3.62, 8.21, 13.35, 3...
# 2  [18.34, 6.93, 4.41, 9.66, 3.62, 8.21, 13.35, 3...
# 3  [18.34, 6.93, 4.41, 9.66, 3.62, 8.21, 13.35, 3...
# 4  [18.34, 6.93, 4.41, 9.66, 3.62, 8.21, 13.35, 3...

# %%
print(cities_data)
# Out:
# {'coord': {'lon': -156.47, 'lat': 20.89}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 81.16, 'pressure': 1015, 'humidity': 69, 'temp_min': 78.8, 'temp_max': 82.4}, 'visibility': 16093, 'wind': {'speed': 23.04, 'deg': 40, 'gust': 13.4}, 'clouds': {'all': 75}, 'dt': 1531014960, 'sys': {'type': 1, 'id': 823, 'message': 0.0206, 'country': 'US', 'sunrise': 1531065052, 'sunset': 1531113066}, 'id': 5847411, 'name': 'Kahului', 'cod': 200}

# %%
#Lat vs Temp
plt.scatter(lng, temp, marker="o", facecolors="green", edgecolors="black", alpha=0.75)
plt.title("Latitude vs. Temperature (F)")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid()

# %%
#Lat vs Humidity
plt.scatter(lng, humidity, marker="o", facecolors="red", edgecolors="black")
plt.title("Latitude vs. Humidity (%)")
plt.ylabel("Humdity (%)")
plt.xlabel("Latitude")
plt.grid()

# %%
#Lat vs Cloudiness
plt.scatter(lng, cloudiness, marker="o", facecolor="blue", edgecolor="black")
plt.title("Latitude vs. Cloudiness (%)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()

# %%
#Lat vs Wind Speed
plt.scatter(lng, wind, marker="o", facecolor="yellow", edgecolor="black")
plt.title("Latitude vs. Wind Speed (mph)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
